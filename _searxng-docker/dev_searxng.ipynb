# %%
# !pip install pydantic -q

# %%
import requests
from typing import List, Optional, Dict, Any
from pydantic import BaseModel
from urllib.parse import urlencode

# Equivalent to `getSearxngApiEndpoint()` in TypeScript
def get_searxng_api_endpoint() -> str:
    return "http://localhost:8080"  # Or your Docker container address

class SearxngSearchOptions(BaseModel):
    categories: Optional[List[str]] = None
    engines: Optional[List[str]] = None
    language: Optional[str] = None
    pageno: Optional[int] = None

class SearxngSearchResult(BaseModel):
    title: str
    url: str
    img_src: Optional[str] = None
    thumbnail_src: Optional[str] = None
    thumbnail: Optional[str] = None
    content: Optional[str] = None
    author: Optional[str] = None
    iframe_src: Optional[str] = None

class SearxngSearchResponse(BaseModel):
    results: List[SearxngSearchResult]
    suggestions: List[str]

def search_searxng(query: str, opts: Optional[SearxngSearchOptions] = None) -> SearxngSearchResponse:
    base_url = f"{get_searxng_api_endpoint()}/search?format=json"
    params = {'q': query}

    if opts:
        for key, value in opts.model_dump(exclude_none=True).items():
            if isinstance(value, list):
                params[key] = ','.join(value)
            else:
                params[key] = str(value)

    response = requests.get(base_url, params=params)
    response.raise_for_status()
    data = response.json()

    return SearxngSearchResponse(results=data['results'], suggestions=data.get('suggestions', []))

# %%
opts = SearxngSearchOptions(
    engines=["google", "bing", "DuckDuckGo"],
    language="en",
    pageno=1
)
result = search_searxng("What is the definition of the best pizza?", opts)

# %%
result.results[0].url
# Out:
# 'https://www.reddit.com/r/Pizza/comments/1dfj86w/what_makes_a_perfect_pizza_this_gets_close_for_me/'

# %%
len(result.results)
# Out:
# 10

# %%
import requests

def scrape_jina_ai(url:str)->str:
    response = requests.get("https://r.jina.ai/"+url)
    return response.text

# %%
class Document(BaseModel):
    page_content:str
    metadata:Dict[str, Any]

documents:List[Document] = []

for r in result.results:
    text = scrape_jina_ai(url=r.url)
    documents.append(Document(page_content=text, metadata={"source": r.url, "title": r.title}))

# %%
len(documents)
# Out:
# 10

# %%
idx = 1
print(documents[idx].metadata['source'])
print(documents[idx].page_content)
# Out:
# https://www.pizzauniversity.org/how-to-identify-good-pizza-in-8-easy-steps
# Title: How to Identify Good Pizza in 8 Easy Steps – Pizza University & Culinary Arts Center
#
# URL Source: https://www.pizzauniversity.org/how-to-identify-good-pizza-in-8-easy-steps
#
# Markdown Content:
# How to Identify Good Pizza in 8 Easy Steps – Pizza University & Culinary Arts Center
# ===============
#
# [![Image 5](https://www.pizzauniversity.org/wp/wp-content/uploads/2023/09/Pizza-University-logo-horizontal-2.png)](https://www.pizzauniversity.org/)
#
# *   [Intensive Courses](https://www.pizzauniversity.org/pizzauu-courses/)
# *   [Online Courses](https://www.pizzauniversity.org/online-courses/)
# *   [Gift Cards](https://www.pizzauniversity.org/gift-cards/)
# *   [Recreational Classes](https://www.pizzauniversity.org/recreational-classes/)
# [![Image 7](https://www.pizzauniversity.org/wp/wp-content/uploads/2019/10/Identify-8-Steps.jpg)](https://www.pizzauniversity.org/how-to-identify-good-pizza-in-8-easy-steps/)
#
# How to Identify Good Pizza in 8 Easy Steps
# ==========================================
#
# *   Posted by [Jill Connor](https://www.pizzauniversity.org/author/jconnor/)
# *   Categories [Pizza University How-To](https://www.pizzauniversity.org/category/pizza-university-how-to/)
# *   Date October 25, 2019
#
# People often ask us what they should look for in a good pizza. When we host events such as the [US Pizza Cup](https://www.pizzauniversity.org/u-s-pizza-cup/), being able to define various features of a proper slice is extremely important. In honor of National Pizza Month, we sat down with our Culinary Director, Pizzaiolo/Chef and longtime artisan baker [Felice Colucci](https://www.pizzauniversity.org/about/) to give us his strategy for selecting the best pizza possible. This is what he had to say. When you first look at the pizza – it is important to notice:
#
# **Crust and border**– First look at the [crust](https://lesaffreyeast.com/) and the border of the pizza. If it contains a lot of air – it will be light, crisp and good.  If it is full of dough and heavy, however, it means that the pizza has not been leavened properly.
#
# **Balance** – the ratio of [tomato](https://www.compagniamercantiledoltremare.com/prodotti/pomodori-pelati-ciao/) and mozzarella, or toppings on the pizza in general, is very important. The toppings should complement the base of the pizza. The dough is not just a blank canvas…it is the foundation of the pizza. If it is not good, there is no topping that can redeem it. The toppings should enhance the base and harmonize perfectly with it – without taking over the show. Too many toppings on a pizza are not a good thing.
#
# ![Image 8: Pizza bread cell structure with italina chef](https://www.pizzauniversity.org/wp/wp-content/uploads/2019/10/72640659_780276379071804_4915953452704221371_n-Cropped-1-1024x768.jpg)
#
# ![Image 9: uncooked pizzas with tomato sauce getting topped with mozzarella cheese](https://www.pizzauniversity.org/wp/wp-content/uploads/2019/10/PIC_5439-Cropped-4-1024x767.jpg)
#
# **Don’t overcook the cheese!** You can tell whether the [mozzarella](https://www.grande.com/) is burnt and when it is not. Good pizzas do not have burnt cheese on top.
#
# **Avoid greasy mozzarella!** Pizza that is covered with orange grease happens because the tomato mix with cheese – it is a sign of an imbalance of ingredients. The mozzarella should be just enough to lightly cover most of the pizza without mixing with the sauce – and vice versa.
#
# **The color of tomatoes** – Tomato toppings have to be a bright red which symbolizes freshness. If the tomato sauce becomes dark, it will have too many conflicting flavors because it has already been cooked.  Authentic Neapolitan-style pizza is never topped with cooked sauce.
#
# **When you go to eat** **pizza – this is what you should look for:**
#
# *   **The** _**cottura**_ – has it been cooked evenly?  If it is cooked through that is great. But,  if it is white – if the pizzaiolo used a lot of flour under the pizza, It becomes yellow and it burns underneath – those are signs of an undercooked pizza.
#
# *   **Basil** – if it is Neapolitan and cooks in 90 seconds, you can put the basil on prior to cooking the pizza and it will remain moist – but if not it has to be put on after. Basil should taste fresh and bright when pizza is cooked properly. If it is burned, it won’t taste good. If the pizza is cooked New York style with lower, longer cooking temperatures, the basil may still burn – so it is better to add it afterward.
#
# *   **The amount of oil** – The amount of [olive oil](https://corto-olive.com/) used to top a pizza depends on the toppings. If you make a light pizza you can put oil, but if you already have oil in the meat, you can’t put more oil – it will be too greasy.
#
# ![Image 10: olive oil being poured on uncooked neaplitan pizza](https://www.pizzauniversity.org/wp/wp-content/uploads/2019/10/PIC_3503-Cropped.jpg)
#
# [Contact us here to](https://www.pizzauniversity.org/contact-us/) discuss classes with Culinary Director Felice Colucci.
#
# *   Share:
# *   [](https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.pizzauniversity.org%2Fhow-to-identify-good-pizza-in-8-easy-steps%2F "Facebook")
#
# *   [](https://twitter.com/share?url=https%3A%2F%2Fwww.pizzauniversity.org%2Fhow-to-identify-good-pizza-in-8-easy-steps%2F&text=How%20to%20Identify%20Good%20Pizza%20in%208%20Easy%20Steps "Twitter")
#
# *   [](http://pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.pizzauniversity.org%2Fhow-to-identify-good-pizza-in-8-easy-steps%2F&description=In%20honor%20of%20National%20Pizza%20Month%2C%20we%20sat%20down%20with%20our%20Culinary%20Director%2C%20Pizzaiolo%2FChef%20and%20longtime%20artisan%20baker%20Felice%20Colucci%20to%20give%20us%20his%20strategy%20for%20selecting%20the%20best%20pizza%20possible%20and%20this%20is%20what%20he%20had%20to%20say.%20&media=https%3A%2F%2Fwww.pizzauniversity.org%2Fwp%2Fwp-content%2Fuploads%2F2019%2F10%2FIdentify-8-Steps.jpg "Pinterest")
#
#
# [](https://www.pizzauniversity.org/author/jconnor/)
#
# [Jill Connor](https://www.pizzauniversity.org/author/jconnor/)
#
# Previous post
#
# ##### [7 Guaranteed Ways to Run Your Pizza Business Better](https://www.pizzauniversity.org/7-guaranteed-ways-to-run-your-pizza-business-better/)
#
# October 25, 2019
#
# Next post
#
# ##### [The Top 5 Tips to Become a Truffle Expert](https://www.pizzauniversity.org/the-top-5-tips-to-become-a-truffle-expert/)
#
# November 15, 2019
#
# ### You may also like
#
# [![Image 11: flour1](https://www.pizzauniversity.org/wp/wp-content/uploads/2021/05/flour1-scaled-300x200.jpg)](https://www.pizzauniversity.org/everything-you-need-to-know-about-flour-for-pizza-making-in-5-easy-steps/ "Everything You Need to Know About Flour for Pizza-Making in 5 Easy Steps")
#
# ##### [Everything You Need to Know About Flour for Pizza-Making in 5 Easy Steps](https://www.pizzauniversity.org/everything-you-need-to-know-about-flour-for-pizza-making-in-5-easy-steps/)
#
# 12 May, 2021
#
# [![Image 12: 236 Copy](https://www.pizzauniversity.org/wp/wp-content/uploads/2021/02/236-Copy-scaled-300x200.jpg)](https://www.pizzauniversity.org/dont-throw-out-torn-dough-try-this-instead/ "Don’t Throw Out Torn Dough….Try this Instead!")
#
# ##### [Don’t Throw Out Torn Dough….Try this Instead!](https://www.pizzauniversity.org/dont-throw-out-torn-dough-try-this-instead/)
# [![Image 27](https://www.pizzauniversity.org/wp/wp-content/uploads/2023/09/stanislaus.jpg)](https://stanislaus.com/)
#
# [![Image 28](https://www.pizzauniversity.org/wp/wp-content/uploads/2024/03/partanna-e1724790195736.png)](https://partannafoods.com/?srsltid=AfmBOorwkgpNDAfcLwR7Dsoo3SFavWbeSUo0JedP7DEkP9OiUpU_-3lE)
#
# [![Image 29: Slice-Logo-Screen_Yellow-BlackType](https://www.pizzauniversity.org/wp/wp-content/uploads/2024/08/Slice-Logo-Screen_Yellow-BlackType-scaled-100x100.jpg)](https://slice.com/)
#
# Gold Partners
# -------------
#
# [![Image 30](https://www.pizzauniversity.org/wp/wp-content/uploads/2023/09/ezzo-1.jpg)](http://www.ezzo.com/)
#
# Silver Partners
# ---------------
#
# [![Image 31](https://www.pizzauniversity.org/wp/wp-content/uploads/2023/09/mikes-hot-honey-1.jpg)](https://mikeshothoney.com/)
#
# [![Image 32](https://www.pizzauniversity.org/wp/wp-content/uploads/2023/09/urbani-truffles-1.jpg)](https://www.urbani.com/)
#
# [![Image 33](https://www.pizzauniversity.org/wp/wp-content/uploads/2024/03/GOLFERA-solo-e1724790230439.png)](https://www.golfera.us/)
#
# ### Stay in Touch
#
# [Twitter](https://twitter.com/PizzaUniv?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor) [Facebook-f](https://www.facebook.com/PizzaUniversity/) [Tiktok](https://www.tiktok.com/@pizza_university) [Youtube](https://www.youtube.com/@thepizzauniversityculinary270) [Instagram](https://www.instagram.com/thepizzauniversity/?hl=en) [Linkedin](https://www.linkedin.com/company/thepizzauniversity/)
#
# Ask us anything
# ---------------
#
# ![Image 34: Pizza University Logo image](https://www.pizzauniversity.org/wp/wp-content/uploads/2023/04/Untitled-design-2023-04-25T161045.986.png)
#
# #### Events
#
# *   [Intensive Classes](https://www.pizzauniversity.org/pizzauu-courses/)
# *   [Culinary Workshops](https://www.pizzauniversity.org/culinary-workshop/)
# *   [Pizza Wars](https://www.pizzauniversity.org/pizza-wars/)
# *   [Kids and Family Events](https://www.pizzauniversity.org/culinary-workshop/)
#
# #### Get Started
#
# *   [Blog](https://blog.pizzauniversity.org/)
# *   [Gallery](https://www.pizzauniversity.org/gallery/)
# *   [Discounts](https://www.pizzauniversity.org/discounts/)
# *   [Testimonials](https://www.pizzauniversity.org/testimonial-page/)
#
# #### About
#
# *   [About Us](https://www.pizzauniversity.org/about/)
# *   [Contact Us](https://www.pizzauniversity.org/contact-us/)
# *   [Our Partners](https://www.pizzauniversity.org/partners/)
# *   [Terms and Conditions](https://www.pizzauniversity.org/student-enrollment-agreement-terms-and-conditions/)
# *   [Privacy Policy](https://www.pizzauniversity.org/privacy-policy/)
# *   [Return Policy](https://www.pizzauniversity.org/return-policy/)
#
# © 2023 Pizza University & Culinary Arts Center
